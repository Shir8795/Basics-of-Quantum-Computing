# %%
# import qiskit

# help(qiskit)


# ============================================================
# QISKIT MODULE TREE: WHAT IS INSIDE WHAT
# ============================================================

# ============================================================
# QISKIT TOP-LEVEL MODULES / PACKAGES
# ============================================================

# qiskit
# |
# |-- qiskit.circuit          # circuits, gates, registers, parameters
# |-- qiskit.quantum_info     # states, operators, density matrices, Paulis
# |-- qiskit.visualization    # plots, histograms, Bloch sphere, circuit drawings
# |-- qiskit.transpiler       # converts circuits to hardware/basis gates
# |-- qiskit.primitives       # Sampler and Estimator workflows
# |-- qiskit.providers        # backend/job interfaces
# |-- qiskit.converters       # circuit <-> DAG conversion
# |-- qiskit.dagcircuit       # DAG representation of circuits
# |-- qiskit.synthesis        # unitary/gate/circuit synthesis tools
#
# Separate but commonly used:
#
# qiskit_aer                  # simulators and noise models
# qiskit_ibm_runtime          # IBM Quantum hardware/cloud execution



# ============================================================
# qiskit.circuit
# ============================================================

# qiskit
# |
# |-- qiskit.circuit                         # MODULE
# |   |
# |   |-- QuantumCircuit                     # class
# |   |-- QuantumRegister                    # class
# |   |-- ClassicalRegister                  # class
# |   |-- Gate                               # class
# |   |-- Instruction                        # class
# |   |-- Parameter                          # class
# |   |-- ParameterVector                    # class
# |   |
# |   |-- qiskit.circuit.library             # SUBMODULE
# |   |   |
# |   |   |-- XGate                          # class
# |   |   |-- HGate                          # class
# |   |   |-- CXGate                         # class
# |   |   |-- CCXGate                        # class
# |   |   |-- UnitaryGate                    # class
# |   |   |-- UGate                          # class
# |   |   |-- PhaseGate                      # class
# |   |   |-- Initialize                     # class
# |   |   |-- QFT                            # class
# |   |   |-- GroverOperator                 # class
# |   |   |-- TwoLocal                       # class
# |   |   |-- EfficientSU2                   # class
# |   |   |-- RealAmplitudes                 # class
# |   |   |-- PauliEvolutionGate             # class
# |   |
# |   |-- qiskit.circuit.classical           # SUBMODULE
# |   |   |
# |   |   |-- classical-bit logic expressions
# |   |
# |   |-- qiskit.circuit.controlflow         # SUBMODULE
# |   |   |
# |   |   |-- if_else
# |   |   |-- while_loop
# |   |   |-- for_loop
# |   |   |-- switch
# |   |
# |   |-- qiskit.circuit.exceptions          # SUBMODULE
# |   |   |
# |   |   |-- CircuitError
#
#
# Meaning:
#
# qiskit.circuit is the main circuit module.
# qiskit.circuit.library is inside qiskit.circuit.
# So:
#
# qiskit
#   -> circuit
#       -> library
#           -> UnitaryGate
#
# Full path:
#
# qiskit.circuit.library.UnitaryGate
#
# Import:
#
# from qiskit.circuit.library import UnitaryGate


# ============================================================
# qiskit.quantum_info
# ============================================================

# qiskit
# |
# |-- qiskit.quantum_info                    # MODULE
# |   |
# |   |-- Statevector                        # class
# |   |-- DensityMatrix                      # class
# |   |-- Operator                           # class
# |   |-- Pauli                              # class
# |   |-- SparsePauliOp                      # class
# |   |-- Clifford                           # class
# |   |-- StabilizerState                    # class
# |   |
# |   |-- partial_trace                      # function
# |   |-- state_fidelity                     # function
# |   |-- purity                             # function
# |   |-- entropy                            # function
# |   |
# |   |-- qiskit.quantum_info.operators      # SUBMODULE
# |   |   |
# |   |   |-- Operator
# |   |   |-- Pauli
# |   |   |-- SparsePauliOp
# |   |   |-- Clifford
# |   |
# |   |-- qiskit.quantum_info.states         # SUBMODULE
# |   |   |
# |   |   |-- Statevector
# |   |   |-- DensityMatrix
# |   |   |-- StabilizerState
# |   |
# |   |-- qiskit.quantum_info.analysis       # SUBMODULE
# |   |   |
# |   |   |-- state_fidelity
# |   |   |-- purity
# |   |   |-- entropy
# |   |
# |   |-- qiskit.quantum_info.synthesis      # SUBMODULE
# |   |
# |   |-- qiskit.quantum_info.random         # SUBMODULE
# |       |
# |       |-- random_statevector
# |       |-- random_density_matrix
# |       |-- random_unitary
# |       |-- random_pauli


# ============================================================
# qiskit.visualization
# ============================================================

# qiskit
# |
# |-- qiskit.visualization                   # MODULE
# |   |
# |   |-- plot_histogram                     # function
# |   |-- plot_bloch_vector                  # function
# |   |-- plot_bloch_multivector             # function
# |   |-- plot_state_city                    # function
# |   |-- plot_state_qsphere                 # function
# |   |-- plot_state_hinton                  # function
# |   |-- circuit_drawer                     # function


# ============================================================
# qiskit.transpiler
# ============================================================

# qiskit
# |
# |-- qiskit.transpiler                      # MODULE
# |   |
# |   |-- transpile                          # function usually imported from qiskit
# |   |-- CouplingMap                        # class
# |   |-- Target                             # class
# |   |-- PassManager                        # class
# |   |
# |   |-- qiskit.transpiler.passes           # SUBMODULE
# |   |   |
# |   |   |-- optimization passes
# |   |   |-- layout passes
# |   |   |-- routing passes
# |   |   |-- synthesis passes
# |   |
# |   |-- qiskit.transpiler.preset_passmanagers  # SUBMODULE
# |       |
# |       |-- generate_preset_pass_manager


# ============================================================
# qiskit.primitives
# ============================================================

# qiskit
# |
# |-- qiskit.primitives                      # MODULE
# |   |
# |   |-- StatevectorSampler                 # class
# |   |-- StatevectorEstimator               # class
# |   |-- BackendSamplerV2                   # class
# |   |-- BackendEstimatorV2                 # class
#
# Meaning:
#
# Sampler   -> returns probabilities / sampled bitstrings
# Estimator -> returns expectation values <psi|H|psi>


# ============================================================
# qiskit.providers
# ============================================================

# qiskit
# |
# |-- qiskit.providers                       # MODULE
# |   |
# |   |-- Backend                            # class-like backend interface
# |   |-- Job                                # class-like job interface
# |   |-- Options                            # class
# |   |
# |   |-- qiskit.providers.fake_provider     # SUBMODULE
#       |
#       |-- GenericBackendV2
#
# Backend = device or simulator.
# Job = submitted execution.
# Result = output after job finishes.


# ============================================================
# qiskit.converters
# ============================================================

# qiskit
# |
# |-- qiskit.converters                      # MODULE
# |   |
# |   |-- circuit_to_dag                     # function
# |   |-- dag_to_circuit                     # function
#
# DAG = directed acyclic graph representation of a circuit.
# Used internally by transpiler.


# ============================================================
# qiskit.dagcircuit
# ============================================================

# qiskit
# |
# |-- qiskit.dagcircuit                      # MODULE
#     |
#     |-- DAGCircuit                         # class
#
# Lower-level circuit graph representation.
# Mostly used for transpiler/pass writing.


# ============================================================
# qiskit.synthesis
# ============================================================

# qiskit
# |
# |-- qiskit.synthesis                       # MODULE
#     |
#     |-- unitary synthesis tools
#     |-- Clifford synthesis tools
#     |-- permutation synthesis tools
#     |-- evolution synthesis tools
#
# Used for decomposing abstract unitaries/gates into real gate sequences.


# ============================================================
# qiskit_aer
# ============================================================

# qiskit_aer                               # SEPARATE PACKAGE, not inside qiskit
# |
# |-- AerSimulator                         # class
# |
# |-- qiskit_aer.noise                     # SUBMODULE
#     |
#     |-- NoiseModel
#     |-- depolarizing_error
#     |-- amplitude_damping_error
#     |-- phase_damping_error
#     |-- thermal_relaxation_error
#
# Important:
#
# qiskit_aer is installed separately.
# It is not exactly qiskit.circuit or qiskit.quantum_info.
# It is a simulator package used with Qiskit circuits.


# ============================================================
# qiskit_ibm_runtime
# ============================================================

# qiskit_ibm_runtime                       # SEPARATE PACKAGE
# |
# |-- QiskitRuntimeService
# |-- SamplerV2
# |-- EstimatorV2
#
# Used for IBM Quantum hardware/cloud execution.


# ============================================================
# COMPLETE SIMPLE HIERARCHY
# ============================================================

# qiskit
# |
# |-- circuit
# |   |-- library
# |   |-- classical
# |   |-- controlflow
# |   |-- exceptions
# |
# |-- quantum_info
# |   |-- states
# |   |-- operators
# |   |-- analysis
# |   |-- random
# |   |-- synthesis
# |
# |-- visualization
# |
# |-- transpiler
# |   |-- passes
# |   |-- preset_passmanagers
# |
# |-- primitives
# |
# |-- providers
# |   |-- fake_provider
# |
# |-- converters
# |
# |-- dagcircuit
# |
# |-- synthesis
#
#
# Separate but commonly used with Qiskit:
#
# qiskit_aer
# |-- noise
#
# qiskit_ibm_runtime


# ============================================================
# ONE EXAMPLE OF FULL PATHS
# ============================================================

# qiskit.QuantumCircuit
# qiskit.circuit.QuantumCircuit
#
# qiskit.circuit.library.UnitaryGate
# qiskit.circuit.library.QFT
# qiskit.circuit.library.Initialize
#
# qiskit.quantum_info.Statevector
# qiskit.quantum_info.DensityMatrix
# qiskit.quantum_info.Operator
# qiskit.quantum_info.SparsePauliOp
#
# qiskit.visualization.plot_histogram
#
# qiskit.transpiler.PassManager
# qiskit.transpiler.passes
#
# qiskit.primitives.StatevectorSampler
# qiskit.primitives.StatevectorEstimator
#
# qiskit.providers.fake_provider.GenericBackendV2
#
# qiskit_aer.AerSimulator
# qiskit_aer.noise.NoiseModel
