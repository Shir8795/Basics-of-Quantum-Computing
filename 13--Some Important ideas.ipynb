# %%
# ============================================================
# UNIVERSAL SINGLE-QUBIT GATES — KEY IDENTITIES (ONE BOX)
# ============================================================

# --- Hadamard decomposition ---
# H = Rz(π/2) Rx(π/2) Rz(π/2)
# → Hadamard can be built from rotations (useful for hardware)

# --- Pauli vector identity ---
# (n̂ · σ)^2 = I
# → enables exponential simplification:
#   exp(-iθ n·σ/2) = cos(θ/2)I - i sin(θ/2)(n·σ)

# --- Bloch sphere representation (λ → r) ---
# ρ = (I + r · σ)/2
# → r = Bloch vector, |r|=1 (pure), |r|<1 (mixed)

# --- Conjugation identity ---
# X Ry(θ) X = Ry(-θ)
# → X flips rotation direction about Y

# --- General unitary form ---
# U = e^{iα} Rn(θ)
# → any single-qubit gate = rotation + global phase

# --- Z–Y decomposition (core theorem) ---
# U = e^{iα} Rz(β) Ry(γ) Rz(δ)
# → minimal universal decomposition (basis of U3)

# --- Convert Z↔X using Hadamard ---
# H Z H = X,   H X H = Z,   H Y H = -Y
# → basis change between X and Z axes

# --- X–Y decomposition ---
# U = e^{iα} Rx(β) Ry(-γ) Rx(δ)
# → obtained via conjugation with H

# --- A X B X C decomposition ---
# U = e^{iα} A X B X C,   with ABC = I
# → structured synthesis using X gates

# --- T gate transformation ---
# H T H = Rx(π/4)
# → convert Z-rotation to X-rotation

# H Rz(θ) H = Rx(θ)
# H Rx(θ) H = Rz(θ)
# H Ry(θ) H = Ry(-θ)
