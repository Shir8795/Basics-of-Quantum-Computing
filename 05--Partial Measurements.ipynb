# %%
from qiskit.quantum_info import *
from qiskit . visualization import plot_histogram
from numpy import sqrt
from IPython.display import Math, display

# More than one qubit here 3 qubits so 1 X 8 or 8 X 1

W = Statevector ([0 , 1, 1, 0, 1, 0, 0, 0] / sqrt(3))
display(W.draw("latex"))

# Measure Partially
# [n] means Measure qubit n in LITTLE ENDIAN means rightmost qubit is 1st qubit or 0th qubit.
# we want a measurement on rightmost qubit here.

result , newsv = W.measure ([0]) 
print( f"Measured: {result}\nState after measurement:")
newsv.draw("latex")
# Out:
# $$\frac{\sqrt{3}}{3} |001\rangle+\frac{\sqrt{3}}{3} |010\rangle+\frac{\sqrt{3}}{3} |100\rangle$$
# Measured: 0
# State after measurement:
# $$\frac{\sqrt{2}}{2} |010\rangle+\frac{\sqrt{2}}{2} |100\rangle$$
